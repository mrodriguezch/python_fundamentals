# %% [markdown]
# # Archivos

# %%
#1.- athlete_events.csv
#2.- PopularCreativeTypes.csv

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
datos1 = pd.read_csv("C:\\Code\\python_fundamentals\\athlete_events.csv")#ruta completa

# %%
datos1 = pd.read_csv("athlete_events.csv")#ruta relativa

# %%
datos2 = pd.read_csv("PopularCreativeTypes.csv")

# %%
datos1["Games"].unique().tolist() #obtener datos de una columna y sacar la lista sin repetir
# Out:
# '1992 Summer'

# %%
datos1["Sport"] == "Judo"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Sport, Length: 271116, dtype: bool

# %%
datosJudo = datos1[datos1["Sport"] == "Judo"]

# %%
datosFootball = datos1[datos1["Sport"] == "Football"]

# %%
datosFootball["Sex"].count() #conteo no diferenciado
# Out:
# 6745

# %%
datosFootball["Sex"].value_counts() #conteo diferenciado
# Out:
# M    5733
# F    1012
# Name: Sex, dtype: int64

# %%
datosFootball["Age"].max()
# Out:
# 40.0

# %%
datosFootball["Age"].min()
# Out:
# 15.0

# %%
datosFootball[datosFootball["Age"]==40]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 155668   78145  Margarete Maria "Meg" Pioresan   F  40.0   175.0    64.0
# 262097  131136                    Oros Witarsa   M  40.0     NaN     NaN
#
#              Team  NOC        Games  Year  Season       City     Sport  \
# 155668     Brazil  BRA  1996 Summer  1996  Summer    Atlanta  Football
# 262097  Indonesia  INA  1956 Summer  1956  Summer  Melbourne  Football
#
#                             Event Medal
# 155668  Football Women's Football   NaN
# 262097    Football Men's Football   NaN

# %%
datosFootball[datosFootball["Age"]==15]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# 128439    75.0                          Ghana  GHA  1992 Summer  1992  Summer
# 156711     NaN  Christian Brothers' College-1  USA  1904 Summer  1904  Summer
# 180261    54.0                       Thailand  THA  1968 Summer  1968  Summer
# 188957    60.0                       Thailand  THA  1968 Summer  1968  Summer
# 208319     NaN                          Egypt  EGY  1936 Summer  1936  Summer
#
# ...

# %%
OrdPeso = datosFootball.sort_values("Weight")

# %%
OrdPeso
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 268586  134370  Albert Ferdinand "Al" Zerhusen   M  24.0   183.0    28.0
# 103855   52546             Tawa Bolanle Ishola   F  19.0   160.0    45.0
# 164358   82510         Linda Maserame Motlhalo   F  18.0   162.0    47.0
# 196365   98583         Lebohang Ester Ramalepe   F  24.0   155.0    48.0
# 176013   88475                      Vera Okolo   F  19.0   161.0    48.0
# ...        ...                             ...  ..   ...     ...     ...
# 270443  135272                      Zou Wenzhi   M   NaN     NaN     NaN
# 270478  135289            Zzimo Alves Calazans   M  20.0     NaN     NaN
# 270661  135361     Abdullah Sulaiman Zubromawi   M  22.0   176.0     NaN
# 270718  135386                      Enea Zuffi   M  20.0     NaN     NaN
# 270843  135455                 Vjekoslav upani   M  19.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
OrdEdad = datosFootball.sort_values("Age")
OrdEdad
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 268805  134485                             Zhang Jinhai   M   NaN     NaN
# 269530  134866                            Zhu Yongqiang   M   NaN     NaN
# 269870  135025                      Francisc Zimmermann   M   NaN     NaN
# 270443  135272                               Zou Wenzhi   M   NaN     NaN
# 270456  135283         Mohamed Abdel Rahman Tati Zouita   M   NaN   174.0
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
OrdEdad = datosFootball.sort_values("Age")
OrdEdad
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 268805  134485                             Zhang Jinhai   M   NaN     NaN
# 269530  134866                            Zhu Yongqiang   M   NaN     NaN
# 269870  135025                      Francisc Zimmermann   M   NaN     NaN
# 270443  135272                               Zou Wenzhi   M   NaN     NaN
# 270456  135283         Mohamed Abdel Rahman Tati Zouita   M   NaN   174.0
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
OrdEdad[OrdEdad["Age"].notna()]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
# ...        ...                                      ...  ..   ...     ...
# 79208    40223              Ryan Joseph Giggs (Wilson-)   M  38.0   180.0
# 188286   94587                Ricardo Piccinini Alburez   M  39.0   185.0
# 22001    11600               Jenny Lynn Bindon (Bourn-)   F  39.0   170.0
# 155668   78145           Margarete Maria "Meg" Pioresan   F  40.0   175.0
# 262097  131136                             Oros Witarsa   M  40.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# ...

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más veterano que ha recibido medalla (oro, plata o bronce)
medallistas=datos1[datos1["Medal"].notna()]
veterano = medallistas["Age"].max()
medallistas[medallistas["Age"] == veterano]
# Out:
#           ID                                           Name Sex   Age  Height  \
# 44584  22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0     NaN
#
#        Weight           Team  NOC        Games  Year  Season    City  \
# 44584     NaN  Great Britain  GBR  1948 Summer  1948  Summer  London
#
#                   Sport                                          Event   Medal
# 44584  Art Competitions  Art Competitions Mixed Painting, Graphic Arts  Silver

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más joven que ha recibido medalla de oro
oros=datos1[datos1["Medal"]=="Gold"]
novato = oros["Age"].min()
oros[oros["Age"] == novato]
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 27207     Switzerland  SUI  1928 Summer  1928  Summer    Amsterdam
# 52010   United States  USA  1960 Summer  1960  Summer         Roma
# 73581           China  CHN  1992 Summer  1992  Summer    Barcelona
# 78544   United States  USA  1936 Summer  1936  Summer       Berlin
# ...

# %%
oros.sort_values(by=["Age"]).head(10)
# Out:
#             ID                                      Name Sex   Age  Height  \
# 268602  134381                               Klaus Zerta   M  13.0   165.0
# 52010    26731        Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0
# 119277   60384                                Kim Yun-Mi   F  13.0   160.0
# 27207    14142                             Hans Bourquin   M  13.0     NaN
# 73581    37398                                Fu Mingxia   F  13.0   160.0
# 78544    39866              Marjorie Gestring (-Redlick)   F  13.0     NaN
# 200704  100797             Aileen Muriel Riggin (-Soule)   F  13.0   142.0
# 69216    35292  Mariya Yevgenyevna Filatova (-Kurbatova)   F  14.0   136.0
# 163440   82042              Sandra Anne Morgan (-Beavis)   F  14.0   167.0
# 172293   86555           Carola Nitschke (-Beraktschjan)   F  14.0   172.0
#
#         Weight           Team  NOC        Games  Year  Season         City  \
# ...

# %%
#Encuentra al competidor más ganador de la historia y crea un csv con toda su información.

# %%
ganador = medallistas.groupby(["Name"]).count().sort_values(["Medal"], ascending=False).head(1)

# %%
type(ganador)
# Out:
# pandas.core.frame.DataFrame

# %%
ganador["Medal"].to
# Out:
# pandas.core.series.Series

# %%
type(datos1)
# Out:
# pandas.core.frame.DataFrame

# %%
datos1["Games"]
# Out:
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object
